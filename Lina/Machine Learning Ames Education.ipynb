# %% [markdown]
# # Machine Learning Project - Ames Education

# %% [markdown]
# ## Libraries

# %%
import math
import itertools
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %% [markdown]
# ## Datasets

# %%
ACT = pd.read_csv('Iowa ACT.csv')
grads = pd.read_csv('Iowa grad count.csv')
rank = pd.read_csv('SchoolRanking .csv')
test = pd.read_csv('test.csv')

# %%
ACT.head()
# Out:
#   Analysis Level                  District Name ACT Dist Code      HS Name  \
# 0       District  ADAIR-CASEY CMTY SCH DISTRICT        167342  All Schools
# 1       District  ADAIR-CASEY CMTY SCH DISTRICT        167342  All Schools
# 2       District  ADAIR-CASEY CMTY SCH DISTRICT        167342  All Schools
# 3       District  ADAIR-CASEY CMTY SCH DISTRICT        167342  All Schools
# 4       District  ADAIR-CASEY CMTY SCH DISTRICT        167342  All Schools
#
#    ACT HS Code  Grad Year        N  Avg Eng Avg Math Avg Reading  Avg Sci  \
# 0       999999       2014       19     20.5     21.2        20.7     21.6
# 1       999999       2015  Small N  Small N  Small N     Small N  Small N
# 2       999999       2016       17     18.9     19.4        20.2     19.8
# 3       999999       2017  Small N  Small N  Small N     Small N  Small N
# 4       999999       2018  Small N  Small N  Small N     Small N  Small N
#
# ...

# %%
grads.head()
# Out:
#         Year  County   AEA  District          District Name Diploma Count  \
# 0  2017-2018    42.0   7.0       9.0                  AGWSR            43
# 1  2017-2018    39.0  11.0      18.0            Adair-Casey           NaN
# 2  2017-2018    25.0  11.0      27.0    Adel DeSoto Minburn           122
# 3  2017-2018    75.0  12.0      63.0        Akron Westfield            40
# 4  2017-2018    11.0   5.0      72.0  Albert City-Truesdale           NaN
#
#   Private 4-Year Public 4-Year Community College Private 2-Year  \
# 0              7             9                14              0
# 1            NaN           NaN               NaN            NaN
# 2             27            39                34              0
# 3              1            14                17              0
# 4            NaN           NaN               NaN            NaN
#
#   Other Training Employment Homemaker Military Unknown
# 0              1          4         0        1       7
# ...

# %%
rank.head()
# Out:
#                  AEA           County  \
# 0      Heartland AEA    Dallas County
# 1      Northwest AEA  Plymouth County
# 2      Northwest AEA  Plymouth County
# 3  Great Prairie AEA    Monroe County
# 4     Grant Wood AEA      Linn County
#
#                                         District  \
# 0  Adel DeSoto Minburn Community School District
# 1      Akron Westfield Community School District
# 2      Akron Westfield Community School District
# 3                Albia Community School District
# 4            Alburnett Community School District
#
#                          School_Name DistrictCode_SchoolCode  SchoolType  \
# 0             Adel Elementary School               0027-0409  Elementary
# 1  Akron Westfield Elementary School               0063-0409  Elementary
# 2      Akron Westfield Middle School               0063-0418      Middle
# 3                     Lincoln Center               0081-0427  Elementary
# ...

# %%
test['Neighborhood'].unique()
# Out:
# array(['NAmes', 'Gilbert', 'StoneBr', 'BrDale', 'NPkVill', 'NridgHt',
#        'Blmngtn', 'NoRidge', 'Somerst', 'SawyerW', 'Sawyer', 'NWAmes',
#        'OldTown', 'BrkSide', 'ClearCr', 'SWISU', 'Edwards', 'CollgCr',
#        'Crawfor', 'Blueste', 'IDOTRR', 'Mitchel', 'Timber', 'MeadowV',
#        'Veenker'], dtype=object)

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# ## Part 1: Mapping neighborhood to school district

# %%
storyrank = rank.loc[rank['County'] == 'Story County']

storyrank['School_Name'].unique()
storyrank
# Out:
#                 AEA        County  \
# 9     Heartland AEA  Story County
# 14    Heartland AEA  Story County
# 15    Heartland AEA  Story County
# 38    Heartland AEA  Story County
# 39    Heartland AEA  Story County
# 40    Heartland AEA  Story County
# 156   Heartland AEA  Story County
# 175   Heartland AEA  Story County
# 211   Heartland AEA  Story County
# 244   Heartland AEA  Story County
# 377   Heartland AEA  Story County
# 400   Heartland AEA  Story County
# 528   Heartland AEA  Story County
# 580   Heartland AEA  Story County
# 697   Heartland AEA  Story County
# 698   Heartland AEA  Story County
# 760   Heartland AEA  Story County
# 844   Heartland AEA  Story County
# 1019  Heartland AEA  Story County
# 1097  Heartland AEA  Story County
# 1098  Heartland AEA  Story County
# 1137  Heartland AEA  Story County
# 1146  Heartland AEA  Story County
# 1214  Heartland AEA  Story County
# 1215  Heartland AEA  Story County
# 1255  Heartland AEA  Story County
# ...

# %%
Address = {'Abbie Sawyer Elementary School': '4316 Ontario St', 'Ames Christian School': '925 South 16th Street', 
           'Ames High School': '1921 Ames High Drive', 'Ames Middle School': '3915 Mortensen Road',
           'Edwards Elementary School': ' 820 Miller Ave, Ames, IA 50014', 'Fellows Elementary School': '1400 Mc Kinley',
           'Kate Mitchell Elementary School': '3521 Jewel Dr', 'Meeker Elementary School': '300 20th Street',
           'St Cecilia Elementary School' : '2900 Hoover Avenue', 'Willson Beardshear School': '920 Carroll Ave', 'Nevada Middle School': '1035 15th St, Nevada, IA 50201',
          'Roland-Story High School': '900 Hillcrest Drive, 1009 Story St, Story City, IA 50248' , 'West Elementary': '105 E Main St, Slater, IA 50244', 'Colo-NESCO Intermediate School' : '919 West St, Colo, IA 50056', 'Ballard Community Senior High School' : '701 Ballard Dr, Huxley, IA 50124',
          'Collins-Maxwell Middle/High School' : '400 Metcalf St, Maxwell, IA 50161', 'Ballard Community Middle School' : '509 North Main Ave, Huxley, IA 50124',
          'Gilbert Intermediate School': '103 Mathews Dr, Gilbert, IA 50105', 'Collins-Maxwell Elementary School': '416 4th Ave, Collins, IA 50055', 'Colo-NESCO  Jr./Sr. High School': '919 West St, Colo, IA 50056', 'Central Elementary School': '925 H Ave, Nevada, IA 50201',
          'Colo-Nesco Elementary Learning Center': '407 North Center, Zearing, IA 50278', 'Gilbert  High School': '312 Gretten St, Gilbert, IA 50105', 'Roland-Story Middle School' : '206 S Main St, Roland, IA 50236', 'Roland-Story Elementary School': '900 Hillcrest Dr, Story City, IA 50248', 
          'East Elementary': '505 W 4th St, Cambridge, IA 50046', 'Gilbert Middle School': '201 Mathews Dr, Gilbert, IA 50105', 'Gilbert Elementary School': '109 Rothmoor Dr, Gilbert, IA 50105', 'Nevada High School': '1001 15th St, Nevada, IA 50201',
          'Ballard Middle School': '509 N Main Ave, Huxley, IA 50124', 'Ballard High School': '701 Ballard Dr, Huxley, IA 50124', 'Northwood Pre-School': '3012 Duff Ave, Ames, IA 50010', 'Ballard West Elementary': '105 E Main St, Slater, IA 50244', 'Colo-NESCO  Middle/High School': '919 West St, Colo, IA 50056',
          'Ballard East Elementary': '505 W 4th St, Cambridge, IA 50046', 'Colo-Nesco Elementary School': '407 N Center St, Zearing, IA 50278',
          'Mitchell Elementary School':'3521 Jewel Dr, Ames, IA 50010', 'Sawyer Elementary School': '4316 Ontario St, Ames, IA 50014'}

# %%
Neighborhood_map = {'Abbie Sawyer Elementary School': 'Sawyer', 'Ames Christian School': 'Mitchell', 
           'Ames High School': 'North Ames', 'Ames Middle School': 'Edwards',
           'Edwards Elementary School': ' Edwards', 'Fellows Elementary School': 'North Ames',
           'Kate Mitchell Elementary School': 'Northwest Ames', 'Meeker Elementary School': 'Northwest Ames',
           'St Cecilia Elementary School' : 'North Ames', 'Willson Beardshear School': 'Crawford', 'Nevada Middle School': 'Nevada',
          'Roland-Story High School': 'Story City' , 'West Elementary': 'Slater', 'Colo-NESCO Intermediate School' : 'Colo', 'Ballard Community Senior High School' : 'Huxley',
          'Collins-Maxwell Middle/High School' : 'Maxwell', 'Ballard Community Middle School' : 'Huxley',
          'Gilbert Intermediate School': 'Gilbert', 'Collins-Maxwell Elementary School': 'Collins', 'Colo-NESCO  Jr./Sr. High School': 'Colo', 'Central Elementary School': 'Nevada',
          'Colo-Nesco Elementary Learning Center': 'Zearing', 'Gilbert  High School': 'Gilbert', 'Roland-Story Middle School' : 'Roland', 'Roland-Story Elementary School': 'Story City', 
          'East Elementary': 'Cambridge', 'Gilbert Middle School': 'Gilbert', 'Gilbert Elementary School': 'Gilbert', 'Nevada High School': 'Nevada',
          'Ballard Middle School': 'Huxley', 'Ballard High School': 'Huxley', 'Northwood Pre-School': 'Northwest Ames', 'Ballard West Elementary': 'Slater', 'Colo-NESCO  Middle/High School': 'Colo',
          'Ballard East Elementary': 'Cambridge', 'Colo-Nesco Elementary School': 'Zearing', 'Mitchell Elementary School': 'Mitchell', 'Sawyer Elementary School': 'North Ames' }

# %%
Neighborhood_map
# Out:
# {'Abbie Sawyer Elementary School': 'Sawyer',
#  'Ames Christian School': 'Mitchell',
#  'Ames High School': 'North Ames',
#  'Ames Middle School': 'Edwards',
#  'Edwards Elementary School': ' Edwards',
#  'Fellows Elementary School': 'North Ames',
#  'Kate Mitchell Elementary School': 'Northwest Ames',
#  'Meeker Elementary School': 'Northwest Ames',
#  'St Cecilia Elementary School': 'North Ames',
#  'Willson Beardshear School': 'Crawford',
#  'Nevada Middle School': 'Nevada',
#  'Roland-Story High School': 'Story City',
#  'West Elementary': 'Slater',
#  'Colo-NESCO Intermediate School': 'Colo',
#  'Ballard Community Senior High School': 'Huxley',
#  'Collins-Maxwell Middle/High School': 'Maxwell',
#  'Ballard Community Middle School': 'Huxley',
#  'Gilbert Intermediate School': 'Gilbert',
#  'Collins-Maxwell Elementary School': 'Collins',
#  'Colo-NESCO  Jr./Sr. High School': 'Colo',
#  'Central Elementary School': 'Nevada',
#  'Colo-Nesco Elementary Learning Center': 'Zearing',
# ...

# %%
Neighborhood_namelong = {'NAmes': 'North Ames', 'Gilbert': 'Gilbert', 'StoneBr': 'Stone Brook', 'BrDale': 'Briardale', 
                         'NPkVill': 'Northpark Villa', 'NridgHt': 'Northridge',
       'Blmngtn': 'Bloomington', 'NoRidge': 'Northridge', 'Somerst': 'Somerset', 'SawyerW': 'Sawyer West', 'Sawyer': 'Sawyer',
                         'NWAmes': 'Northwest Ames',
       'OldTown': 'Old Town', 'BrkSide': 'Brookside', 'ClearCr': 'Clear Creek', 'SWISU': 'South & West of Iowa State University', 'Edwards': 'Edwards', 'CollgCr': 'College Creek',
       'Crawfor': 'Crawford', 'Blueste': 'Bluestem', 'IDOTRR': "Iowa DOT and Rail Road", 'Mitchel': 'Mitchell', 'Timber': 'Timberland', 'MeadowV': 'Meadow Village',
       'Veenker': 'Veenker'}

# %% [markdown]
# ## Part 2: Combining education datasets

# %%
storyrank['Address']= storyrank['School_Name'].map(Address)
storyrank['Neighborhood'] = storyrank['School_Name'].map(Neighborhood_map)
# Out:
# /Users/celinasprague/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/celinasprague/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
storyrank
# Out:
#                 AEA        County  \
# 9     Heartland AEA  Story County
# 14    Heartland AEA  Story County
# 15    Heartland AEA  Story County
# 38    Heartland AEA  Story County
# 39    Heartland AEA  Story County
# 40    Heartland AEA  Story County
# 156   Heartland AEA  Story County
# 175   Heartland AEA  Story County
# 211   Heartland AEA  Story County
# 244   Heartland AEA  Story County
# 377   Heartland AEA  Story County
# 400   Heartland AEA  Story County
# 528   Heartland AEA  Story County
# 580   Heartland AEA  Story County
# 697   Heartland AEA  Story County
# 698   Heartland AEA  Story County
# 760   Heartland AEA  Story County
# 844   Heartland AEA  Story County
# 1019  Heartland AEA  Story County
# 1097  Heartland AEA  Story County
# 1098  Heartland AEA  Story County
# 1137  Heartland AEA  Story County
# 1146  Heartland AEA  Story County
# 1214  Heartland AEA  Story County
# 1215  Heartland AEA  Story County
# 1255  Heartland AEA  Story County
# ...

# %%
storyrank.to_csv('storyrank')
