# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns=300 #increase columns shown 
ames = pd.read_csv('./ames.csv')

# %%
ames.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          20       RL        141.0    31770   Pave   NaN      IR1
# 1          20       RH         80.0    11622   Pave   NaN      Reg
# 2          20       RL         81.0    14267   Pave   NaN      IR1
# 3          20       RL         93.0    11160   Pave   NaN      Reg
# 4          60       RL         74.0    13830   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 2         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 3         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 4         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            6            5       1960
# ...

# %%
test = pd.read_csv('./data/test.csv')
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
print (ames.shape)
print (test.shape) #final result should be (1459, 2)
# Out:
# (2930, 80)
# (1459, 80)

# %%
answerkey = pd.merge(test, ames, on=['LotFrontage', 'LotArea','BsmtFinSF1','BsmtUnfSF','TotalBsmtSF','MoSold', 'YrSold'], how='left')

# %%
answerkey.shape
# Out:
# (1470, 153)

# %%
a = answerkey['Id']

import collections
print ([item for item, count in collections.Counter(a).items() if count > 1])

# [1840, 1858, 1859, 2714, 2866]
# Out:
# [1840, 1858, 1859, 2714, 2866]

# %%
answerkey[answerkey['Id'] == 1858]
# Out:
#        Id  MSSubClass_x MSZoning_x  LotFrontage  LotArea Street_x Alley_x  \
# 398  1858            90         RL         64.0     7018     Pave     NaN
# 399  1858            90         RL         64.0     7018     Pave     NaN
# 400  1858            90         RL         64.0     7018     Pave     NaN
# 401  1858            90         RL         64.0     7018     Pave     NaN
# 402  1858            90         RL         64.0     7018     Pave     NaN
#
#     LotShape_x LandContour_x Utilities_x LotConfig_x LandSlope_x  \
# 398        Reg           Lvl      AllPub      Inside         Gtl
# 399        Reg           Lvl      AllPub      Inside         Gtl
# 400        Reg           Lvl      AllPub      Inside         Gtl
# 401        Reg           Lvl      AllPub      Inside         Gtl
# 402        Reg           Lvl      AllPub      Inside         Gtl
#
#     Neighborhood_x Condition1_x Condition2_x BldgType_x HouseStyle_x  \
# ...

# %%
answerkey = answerkey.drop_duplicates(subset=['Id','LotFrontage', 'LotArea','BsmtFinSF1','BsmtUnfSF','TotalBsmtSF','MoSold', 'YrSold'], keep= 'first', inplace=False)
answerkey.head()
# Out:
#      Id  MSSubClass_x MSZoning_x  LotFrontage  LotArea Street_x Alley_x  \
# 0  1461            20         RH         80.0    11622     Pave     NaN
# 1  1462            20         RL         81.0    14267     Pave     NaN
# 2  1463            60         RL         74.0    13830     Pave     NaN
# 3  1464            60         RL         78.0     9978     Pave     NaN
# 4  1465           120         RL         43.0     5005     Pave     NaN
#
#   LotShape_x LandContour_x Utilities_x LotConfig_x LandSlope_x Neighborhood_x  \
# 0        Reg           Lvl      AllPub      Inside         Gtl          NAmes
# 1        IR1           Lvl      AllPub      Corner         Gtl          NAmes
# 2        IR1           Lvl      AllPub      Inside         Gtl        Gilbert
# 3        IR1           Lvl      AllPub      Inside         Gtl        Gilbert
# 4        IR1           HLS      AllPub      Inside         Gtl        StoneBr
#
# ...

# %%
a = answerkey['Id']
print ([item for item, count in collections.Counter(a).items() if count > 1])

print (answerkey.shape)
# Out:
# []
# (1459, 153)

# %%
answerkey = answerkey.reset_index(drop=True)
answerkey = answerkey[['Id','SalePrice']]

# %%
answerkey.head(20)
# Out:
#       Id  SalePrice
# 0   1461     105000
# 1   1462     172000
# 2   1463     189900
# 3   1464     195500
# 4   1465     191500
# 5   1466     175900
# 6   1467     185000
# 7   1468     180400
# 8   1469     171500
# 9   1470     126000
# 10  1471     184000
# 11  1472      96000
# 12  1473     105500
# 13  1474     149900
# 14  1475     120000
# 15  1476     376162
# 16  1477     290941
# 17  1478     275000
# 18  1479     259000
# 19  1480     500000

# %%
answerkey.to_csv('./data/answerkey.csv')
